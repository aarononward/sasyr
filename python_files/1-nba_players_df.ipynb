# %%
#Import dependencies
import pandas as pd
import requests
from pprint import pprint
from config import api_key

# %%
#Save API url
url = "https://api-nba-v1.p.rapidapi.com/players/"

#Query for players in the USA 
querystring = {"country":"USA"}

#input header values
headers = {
	
	#input api key from api key file
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}
#Stores response as a json file in variable response
response = requests.get(url, headers=headers, params=querystring).json()

#pretty print response
pprint(response)
# Out:
# {'errors': [],
#  'get': 'players/',
#  'parameters': {'country': 'USA'},
#  'response': [{'affiliation': 'Baylor/USA',
#                'birth': {'country': 'USA', 'date': '1990-10-06'},
#                'college': 'Baylor',
#                'firstname': 'Quincy',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 2,
#                'lastname': 'Acy',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 4,
#                                         'pos': 'F'}},
#                'nba': {'pro': 6, 'start': 2012},
#                'weight': {'kilograms': '108.9', 'pounds': '240'}},
#               {'affiliation': 'Texas-Austin/USA',
#                'birth': {'country': 'USA', 'date': '1985-07-19'},
#                'college': 'Texas-Austin',
#                'firstname': 'LaMarcus',
#                'height': {'feets': '6', 'inches': '11', 'meters': '2.11'},
#                'id': 8,
#                'lastname': 'Aldridge',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'C-F'}},
#                'nba': {'pro': 15, 'start': 2006},
#                'weight': {'kilograms': '113.4', 'pounds': '250'}},
#               {'affiliation': 'Oklahoma State/USA',
#                'birth': {'country': 'USA', 'date': '1982-01-11'},
#                'college': 'Oklahoma State',
#                'firstname': 'Tony',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 11,
#                'lastname': 'Allen',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 9,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 12, 'start': 2004},
#                'weight': {'kilograms': '96.6', 'pounds': '213'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1982-12-07'},
#                'college': 'Nevada-Las Vegas',
#                'firstname': 'Lou',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 13,
#                'lastname': 'Amundson',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 17,
#                                         'pos': 'F'}},
#                'nba': {'pro': 9, 'start': 2006},
#                'weight': {'kilograms': '99.8', 'pounds': '220'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1978-07-07'},
#                'college': 'Blinn',
#                'firstname': 'Chris',
#                'height': {'feets': '6', 'inches': '10', 'meters': '2.08'},
#                'id': 14,
#                'lastname': 'Andersen',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': None,
#                                         'pos': 'F-C'}},
#                'nba': {'pro': 13, 'start': 2001},
#                'weight': {'kilograms': '111.1', 'pounds': '245'}},
#               {'affiliation': 'Michigan State/USA',
#                'birth': {'country': 'USA', 'date': '1982-10-16'},
#                'college': 'Michigan State',
#                'firstname': 'Alan',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 15,
#                'lastname': 'Anderson',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 9,
#                                         'pos': 'F-G'}},
#                'nba': {'pro': 7, 'start': 2005},
#                'weight': {'kilograms': '99.8', 'pounds': '220'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1989-03-25'},
#                'college': 'Oklahoma State',
#                'firstname': 'James',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 16,
#                'lastname': 'Anderson',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 5,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 4, 'start': 2010},
#                'weight': {'kilograms': '96.6', 'pounds': '213'}},
#               {'affiliation': 'Virginia/USA',
#                'birth': {'country': 'USA', 'date': '1993-11-19'},
#                'college': 'Virginia',
#                'firstname': 'Justin',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 17,
#                'lastname': 'Anderson',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 10,
#                                         'pos': 'F-G'},
#                            'vegas': {'active': True, 'jersey': 19, 'pos': 'F'}},
#                'nba': {'pro': 5, 'start': 2015},
#                'weight': {'kilograms': '104.8', 'pounds': '231'}},
#               {'affiliation': 'UCLA/USA',
#                'birth': {'country': 'USA', 'date': '1993-09-20'},
#                'college': 'UCLA',
#                'firstname': 'Kyle',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 18,
#                'lastname': 'Anderson',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'F-G'}},
#                'nba': {'pro': 7, 'start': 2014},
#                'weight': {'kilograms': '104.3', 'pounds': '230'}},
#               {'affiliation': 'California/USA',
#                'birth': {'country': 'USA', 'date': '1988-05-06'},
#                'college': 'California',
#                'firstname': 'Ryan',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 19,
#                'lastname': 'Anderson',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 33,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2008},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Syracuse/USA',
#                'birth': {'country': 'USA', 'date': '1984-05-29'},
#                'college': 'Syracuse',
#                'firstname': 'Carmelo',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 21,
#                'lastname': 'Anthony',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 7,
#                                         'pos': 'F'}},
#                'nba': {'pro': 18, 'start': 2003},
#                'weight': {'kilograms': '108.0', 'pounds': '238'}},
#               {'affiliation': 'UCLA/USA',
#                'birth': {'country': 'USA', 'date': '1985-06-30'},
#                'college': 'UCLA',
#                'firstname': 'Trevor',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 23,
#                'lastname': 'Ariza',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 1,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2004},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Kansas/USA',
#                'birth': {'country': 'USA', 'date': '1988-03-25'},
#                'college': 'Kansas',
#                'firstname': 'Darrell',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 25,
#                'lastname': 'Arthur',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': None,
#                                         'pos': None}},
#                'nba': {'pro': 9, 'start': 2008},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'Texas-Austin/USA',
#                'birth': {'country': 'USA', 'date': '1987-11-10'},
#                'college': 'Texas-Austin',
#                'firstname': 'D.J.',
#                'height': {'feets': '5', 'inches': '11', 'meters': '1.8'},
#                'id': 28,
#                'lastname': 'Augustin',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 4,
#                                         'pos': 'G'}},
#                'nba': {'pro': 13, 'start': 2008},
#                'weight': {'kilograms': '83.0', 'pounds': '183'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1987-04-29'},
#                'college': 'Arizona State',
#                'firstname': 'Jeff',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 29,
#                'lastname': 'Ayres',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 19,
#                                         'pos': 'F-C'},
#                            'vegas': {'active': True, 'jersey': 12, 'pos': 'F'}},
#                'nba': {'pro': 5, 'start': 2009},
#                'weight': {'kilograms': '113.4', 'pounds': '250'}},
#               {'affiliation': 'Wichita State/USA',
#                'birth': {'country': 'USA', 'date': '1993-03-30'},
#                'college': 'Wichita State',
#                'firstname': 'Ron',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 32,
#                'lastname': 'Baker',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 31,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2016},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Vanderbilt/USA',
#                'birth': {'country': 'USA', 'date': '1996-03-29'},
#                'college': 'Vanderbilt',
#                'firstname': 'Wade',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 33,
#                'lastname': 'Baldwin IV',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'},
#                            'vegas': {'active': True, 'jersey': 2, 'pos': 'G'}},
#                'nba': {'pro': 2, 'start': 2016},
#                'weight': {'kilograms': '90.7', 'pounds': '200'}},
#               {'affiliation': 'North Carolina/USA',
#                'birth': {'country': 'USA', 'date': '1992-05-30'},
#                'college': 'North Carolina',
#                'firstname': 'Harrison',
#                'height': {'feets': '6', 'inches': '8', 'meters': '2.03'},
#                'id': 36,
#                'lastname': 'Barnes',
#                'leagues': {'africa': {'active': True, 'jersey': 40, 'pos': 'F'},
#                            'standard': {'active': True,
#                                         'jersey': 40,
#                                         'pos': 'F'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '102.1', 'pounds': '225'}},
#               {'affiliation': 'Memphis/USA',
#                'birth': {'country': 'USA', 'date': '1991-01-06'},
#                'college': 'Memphis',
#                'firstname': 'Will',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 38,
#                'lastname': 'Barton',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '82.1', 'pounds': '181'}},
#               {'affiliation': 'Louisiana State/USA',
#                'birth': {'country': 'USA', 'date': '1985-04-30'},
#                'college': 'Louisiana State',
#                'firstname': 'Brandon',
#                'height': {'feets': '6', 'inches': '8', 'meters': '2.03'},
#                'id': 39,
#                'lastname': 'Bass',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 30,
#                                         'pos': 'F'}},
#                'nba': {'pro': 11, 'start': 2005},
#                'weight': {'kilograms': '113.4', 'pounds': '250'}},
#               {'affiliation': 'Old Dominion/USA',
#                'birth': {'country': 'USA', 'date': '1989-07-01'},
#                'college': 'Old Dominion',
#                'firstname': 'Kent',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 44,
#                'lastname': 'Bazemore',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 24,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '88.5', 'pounds': '195'}},
#               {'affiliation': 'Florida/USA',
#                'birth': {'country': 'USA', 'date': '1993-06-28'},
#                'college': 'Florida',
#                'firstname': 'Bradley',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 45,
#                'lastname': 'Beal',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 3,
#                                         'pos': 'G'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '93.9', 'pounds': '207'}},
#               {'affiliation': 'Florida State/USA',
#                'birth': {'country': 'USA', 'date': '1996-11-26'},
#                'college': 'Florida State',
#                'firstname': 'Malik',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 46,
#                'lastname': 'Beasley',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'},
#                            'vegas': {'active': True, 'jersey': 25, 'pos': 'G'}},
#                'nba': {'pro': 5, 'start': 2016},
#                'weight': {'kilograms': '84.8', 'pounds': '187'}},
#               {'affiliation': 'Kansas State/USA',
#                'birth': {'country': 'USA', 'date': '1989-01-09'},
#                'college': 'Kansas State',
#                'firstname': 'Michael',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 47,
#                'lastname': 'Beasley',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 30,
#                                         'pos': 'F'},
#                            'vegas': {'active': True, 'jersey': 50, 'pos': 'F'}},
#                'nba': {'pro': 11, 'start': 2008},
#                'weight': {'kilograms': '104.3', 'pounds': '230'}},
#               {'affiliation': "St. Joseph's (PA)/USA",
#                'birth': {'country': 'USA', 'date': '1994-07-04'},
#                'college': "St. Joseph's (PA)",
#                'firstname': "DeAndre'",
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 49,
#                'lastname': 'Bembry',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 95,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2016},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Arkansas/USA',
#                'birth': {'country': 'USA', 'date': '1988-07-12'},
#                'college': 'Arkansas',
#                'firstname': 'Patrick',
#                'height': {'feets': '6', 'inches': '1', 'meters': '1.85'},
#                'id': 53,
#                'lastname': 'Beverley',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'G'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '81.6', 'pounds': '180'}},
#               {'affiliation': 'Kansas/USA',
#                'birth': {'country': 'USA', 'date': '1991-11-22'},
#                'college': 'Kansas',
#                'firstname': 'Tarik',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 56,
#                'lastname': 'Black',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 28,
#                                         'pos': 'F'},
#                            'vegas': {'active': True, 'jersey': 28, 'pos': 'F'}},
#                'nba': {'pro': 4, 'start': 2014},
#                'weight': {'kilograms': '117.9', 'pounds': '260'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1980-02-26'},
#                'college': 'Maryland',
#                'firstname': 'Steve',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 57,
#                'lastname': 'Blake',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 22,
#                                         'pos': 'G'}},
#                'nba': {'pro': 12, 'start': 2003},
#                'weight': {'kilograms': '78.0', 'pounds': '172'}},
#               {'affiliation': 'Kentucky/USA',
#                'birth': {'country': 'USA', 'date': '1989-12-09'},
#                'college': 'Kentucky',
#                'firstname': 'Eric',
#                'height': {'feets': '6', 'inches': '1', 'meters': '1.85'},
#                'id': 59,
#                'lastname': 'Bledsoe',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'}},
#                'nba': {'pro': 11, 'start': 2010},
#                'weight': {'kilograms': '97.1', 'pounds': '214'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1980-04-05'},
#                'college': 'Florida',
#                'firstname': 'Matt',
#                'height': {'feets': '6', 'inches': '10', 'meters': '2.08'},
#                'id': 63,
#                'lastname': 'Bonner',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 15,
#                                         'pos': 'C-F'}},
#                'nba': {'pro': 11, 'start': 2004},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'Kentucky/USA',
#                'birth': {'country': 'USA', 'date': '1996-10-30'},
#                'college': 'Kentucky',
#                'firstname': 'Devin',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 64,
#                'lastname': 'Booker',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 1,
#                                         'pos': 'G'}},
#                'nba': {'pro': 6, 'start': 2015},
#                'weight': {'kilograms': '93.4', 'pounds': '206'}},
#               {'affiliation': 'Clemson/USA',
#                'birth': {'country': 'USA', 'date': '1987-11-25'},
#                'college': 'Clemson',
#                'firstname': 'Trevor',
#                'height': {'feets': '6', 'inches': '8', 'meters': '2.03'},
#                'id': 65,
#                'lastname': 'Booker',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 20,
#                                         'pos': 'F'}},
#                'nba': {'pro': 8, 'start': 2010},
#                'weight': {'kilograms': '103.4', 'pounds': '228'}},
#               {'affiliation': 'Georgia Tech/USA',
#                'birth': {'country': 'USA', 'date': '1984-03-24'},
#                'college': 'Georgia Tech',
#                'firstname': 'Chris',
#                'height': {'feets': '6', 'inches': '11', 'meters': '2.11'},
#                'id': 67,
#                'lastname': 'Bosh',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 1,
#                                         'pos': 'F'}},
#                'nba': {'pro': 13, 'start': 2003},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'Texas-Austin/USA',
#                'birth': {'country': 'USA', 'date': '1990-11-26'},
#                'college': 'Texas-Austin',
#                'firstname': 'Avery',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 68,
#                'lastname': 'Bradley',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 20,
#                                         'pos': 'G'}},
#                'nba': {'pro': 11, 'start': 2010},
#                'weight': {'kilograms': '81.6', 'pounds': '180'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1979-03-11'},
#                'college': 'Duke',
#                'firstname': 'Elton',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 69,
#                'lastname': 'Brand',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 42,
#                                         'pos': 'F'}},
#                'nba': {'pro': 16, 'start': 1999},
#                'weight': {'kilograms': '115.2', 'pounds': '254'}},
#               {'affiliation': 'Florida/USA',
#                'birth': {'country': 'USA', 'date': '1986-03-05'},
#                'college': 'Florida',
#                'firstname': 'Corey',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 70,
#                'lastname': 'Brewer',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 13,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 13, 'start': 2007},
#                'weight': {'kilograms': '85.3', 'pounds': '188'}},
#               {'affiliation': 'Virginia/USA',
#                'birth': {'country': 'USA', 'date': '1992-12-11'},
#                'college': 'Virginia',
#                'firstname': 'Malcolm',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 71,
#                'lastname': 'Brogdon',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 13,
#                                         'pos': 'G'}},
#                'nba': {'pro': 5, 'start': 2016},
#                'weight': {'kilograms': '103.9', 'pounds': '229'}},
#               {'affiliation': 'CalUnited StatesState-Fullerton/USA',
#                'birth': {'country': 'USA', 'date': '1984-09-24'},
#                'college': 'Cal State-Fullerton',
#                'firstname': 'Bobby',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 74,
#                'lastname': 'Brown',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 8,
#                                         'pos': 'G'}},
#                'nba': {'pro': 2, 'start': 2008},
#                'weight': {'kilograms': '79.4', 'pounds': '175'}},
#               {'affiliation': 'California/USA',
#                'birth': {'country': 'USA', 'date': '1996-10-24'},
#                'college': 'California',
#                'firstname': 'Jaylen',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 75,
#                'lastname': 'Brown',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 7,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 5, 'start': 2016},
#                'weight': {'kilograms': '101.2', 'pounds': '223'}},
#               {'affiliation': 'North Carolina State/USA',
#                'birth': {'country': 'USA', 'date': '1990-08-26'},
#                'college': 'North Carolina State',
#                'firstname': 'Lorenzo',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 76,
#                'lastname': 'Brown',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 4,
#                                         'pos': 'G'}},
#                'nba': {'pro': 4, 'start': 2013},
#                'weight': {'kilograms': '85.7', 'pounds': '189'}},
#               {'affiliation': 'Oklahoma State/USA',
#                'birth': {'country': 'USA', 'date': '1992-01-29'},
#                'college': 'Oklahoma State',
#                'firstname': 'Markel',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 77,
#                'lastname': 'Brown',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'},
#                            'vegas': {'active': True, 'jersey': 26, 'pos': 'G'}},
#                'nba': {'pro': 3, 'start': 2014},
#                'weight': {'kilograms': '86.2', 'pounds': '190'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1978-08-23'},
#                'college': 'Lower Merion HS (PA)',
#                'firstname': 'Kobe',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 79,
#                'lastname': 'Bryant',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 24,
#                                         'pos': 'F-G'}},
#                'nba': {'pro': 19, 'start': 1996},
#                'weight': {'kilograms': '96.2', 'pounds': '212'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1988-05-22'},
#                'college': 'Arizona',
#                'firstname': 'Chase',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 81,
#                'lastname': 'Budinger',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 10,
#                                         'pos': 'F'}},
#                'nba': {'pro': 6, 'start': 2009},
#                'weight': {'kilograms': '94.8', 'pounds': '209'}},
#               {'affiliation': 'North Carolina/USA',
#                'birth': {'country': 'USA', 'date': '1991-03-16'},
#                'college': 'North Carolina',
#                'firstname': 'Reggie',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 82,
#                'lastname': 'Bullock',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 25,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 8, 'start': 2013},
#                'weight': {'kilograms': '93.0', 'pounds': '205'}},
#               {'affiliation': 'Michigan/USA',
#                'birth': {'country': 'USA', 'date': '1992-11-12'},
#                'college': 'Michigan',
#                'firstname': 'Trey',
#                'height': {'feets': '6', 'inches': '0', 'meters': '1.83'},
#                'id': 83,
#                'lastname': 'Burke',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 9,
#                                         'pos': 'G'}},
#                'nba': {'pro': 8, 'start': 2013},
#                'weight': {'kilograms': '83.9', 'pounds': '185'}},
#               {'affiliation': 'Colorado/USA',
#                'birth': {'country': 'USA', 'date': '1991-07-20'},
#                'college': 'Colorado',
#                'firstname': 'Alec',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 84,
#                'lastname': 'Burks',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'}},
#                'nba': {'pro': 10, 'start': 2011},
#                'weight': {'kilograms': '97.1', 'pounds': '214'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1980-03-13'},
#                'college': 'Connecticut',
#                'firstname': 'Caron',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 85,
#                'lastname': 'Butler',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 31,
#                                         'pos': 'F'}},
#                'nba': {'pro': 13, 'start': 2002},
#                'weight': {'kilograms': '103.4', 'pounds': '228'}},
#               {'affiliation': 'Marquette/USA',
#                'birth': {'country': 'USA', 'date': '1989-09-14'},
#                'college': 'Marquette',
#                'firstname': 'Jimmy',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 86,
#                'lastname': 'Butler',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 22,
#                                         'pos': 'F'}},
#                'nba': {'pro': 10, 'start': 2011},
#                'weight': {'kilograms': '104.3', 'pounds': '230'}},
#               {'affiliation': 'Georgia/USA',
#                'birth': {'country': 'USA', 'date': '1993-02-18'},
#                'college': 'Georgia',
#                'firstname': 'Kentavious',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 89,
#                'lastname': 'Caldwell-Pope',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'}},
#                'nba': {'pro': 8, 'start': 2013},
#                'weight': {'kilograms': '92.5', 'pounds': '204'}},
#               {'affiliation': 'Murray State/USA',
#                'birth': {'country': 'USA', 'date': '1991-05-21'},
#                'college': 'Murray State',
#                'firstname': 'Isaiah',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 91,
#                'lastname': 'Canaan',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 7,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2013},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Missouri/USA',
#                'birth': {'country': 'USA', 'date': '1986-07-27'},
#                'college': 'Missouri',
#                'firstname': 'DeMarre',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 93,
#                'lastname': 'Carroll',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 9,
#                                         'pos': 'F'}},
#                'nba': {'pro': 11, 'start': 2009},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': 'Kentucky/USA',
#                'birth': {'country': 'USA', 'date': '1993-08-18'},
#                'college': 'Kentucky',
#                'firstname': 'Willie',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 97,
#                'lastname': 'Cauley-Stein',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'C'}},
#                'nba': {'pro': 0, 'start': 2015},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Dominguez HS (CA)/USA',
#                'birth': {'country': 'USA', 'date': '1982-10-02'},
#                'college': 'Dominguez HS (CA)',
#                'firstname': 'Tyson',
#                'height': {'feets': '7', 'inches': '0', 'meters': '2.13'},
#                'id': 101,
#                'lastname': 'Chandler',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 19,
#                                         'pos': 'C'}},
#                'nba': {'pro': 19, 'start': 2001},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'DePaul/USA',
#                'birth': {'country': 'USA', 'date': '1987-05-10'},
#                'college': 'DePaul',
#                'firstname': 'Wilson',
#                'height': {'feets': '6', 'inches': '8', 'meters': '2.03'},
#                'id': 102,
#                'lastname': 'Chandler',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'F'}},
#                'nba': {'pro': 12, 'start': 2007},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'Washington/USA',
#                'birth': {'country': 'USA', 'date': '1997-07-02'},
#                'college': 'Washington',
#                'firstname': 'Marquese',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 104,
#                'lastname': 'Chriss',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 14,
#                                         'pos': 'F'}},
#                'nba': {'pro': 5, 'start': 2016},
#                'weight': {'kilograms': '108.9', 'pounds': '240'}},
#               {'affiliation': 'Syracuse/USA',
#                'birth': {'country': 'USA', 'date': '1991-12-01'},
#                'college': 'Syracuse',
#                'firstname': 'Rakeem',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 105,
#                'lastname': 'Christmas',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 25,
#                                         'pos': 'F'}},
#                'nba': {'pro': 1, 'start': 2015},
#                'weight': {'kilograms': '113.4', 'pounds': '250'}},
#               {'affiliation': 'Xavier/USA',
#                'birth': {'country': 'USA', 'date': '1992-11-01'},
#                'college': 'Xavier',
#                'firstname': 'Semaj',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 106,
#                'lastname': 'Christon',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 6,
#                                         'pos': 'G'},
#                            'vegas': {'active': True,
#                                      'jersey': None,
#                                      'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2016},
#                'weight': {'kilograms': '86.2', 'pounds': '190'}},
#               {'affiliation': 'Belmont University/USA',
#                'birth': {'country': 'USA', 'date': '1991-03-07'},
#                'college': 'Belmont',
#                'firstname': 'Ian',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 108,
#                'lastname': 'Clark',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 2,
#                                         'pos': 'G'}},
#                'nba': {'pro': 6, 'start': 2013},
#                'weight': {'kilograms': '79.4', 'pounds': '175'}},
#               {'affiliation': 'Missouri/USA',
#                'birth': {'country': 'USA', 'date': '1992-06-07'},
#                'college': 'Missouri',
#                'firstname': 'Jordan',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 109,
#                'lastname': 'Clarkson',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'}},
#                'nba': {'pro': 7, 'start': 2014},
#                'weight': {'kilograms': '88.0', 'pounds': '194'}},
#               {'affiliation': 'UCLA/USA',
#                'birth': {'country': 'USA', 'date': '1987-08-23'},
#                'college': 'UCLA',
#                'firstname': 'Darren',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 111,
#                'lastname': 'Collison',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 21,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2009},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Ohio State/USA',
#                'birth': {'country': 'USA', 'date': '1987-10-11'},
#                'college': 'Ohio State',
#                'firstname': 'Mike',
#                'height': {'feets': '6', 'inches': '1', 'meters': '1.85'},
#                'id': 114,
#                'lastname': 'Conley',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 11,
#                                         'pos': 'G'}},
#                'nba': {'pro': 14, 'start': 2007},
#                'weight': {'kilograms': '79.4', 'pounds': '175'}},
#               {'affiliation': 'Notre Dame/USA',
#                'birth': {'country': 'USA', 'date': '1993-01-06'},
#                'college': 'Notre Dame',
#                'firstname': 'Pat',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 115,
#                'lastname': 'Connaughton',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 24,
#                                         'pos': 'G'}},
#                'nba': {'pro': 6, 'start': 2015},
#                'weight': {'kilograms': '94.8', 'pounds': '209'}},
#               {'affiliation': 'Kentucky/USA',
#                'birth': {'country': 'USA', 'date': '1990-08-13'},
#                'college': 'Kentucky',
#                'firstname': 'DeMarcus',
#                'height': {'feets': '6', 'inches': '10', 'meters': '2.08'},
#                'id': 117,
#                'lastname': 'Cousins',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 4,
#                                         'pos': 'C'}},
#                'nba': {'pro': 10, 'start': 2010},
#                'weight': {'kilograms': '122.5', 'pounds': '270'}},
#               {'affiliation': 'Tennessee State/USA',
#                'birth': {'country': 'USA', 'date': '1990-12-14'},
#                'college': 'Tennessee State',
#                'firstname': 'Robert',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 118,
#                'lastname': 'Covington',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 23,
#                                         'pos': 'F'}},
#                'nba': {'pro': 8, 'start': 2013},
#                'weight': {'kilograms': '94.8', 'pounds': '209'}},
#               {'affiliation': 'Marquette/USA',
#                'birth': {'country': 'USA', 'date': '1990-07-06'},
#                'college': 'Marquette',
#                'firstname': 'Jae',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 121,
#                'lastname': 'Crowder',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 99,
#                                         'pos': 'F'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '106.6', 'pounds': '235'}},
#               {'affiliation': 'Duke/USA',
#                'birth': {'country': 'USA', 'date': '1990-08-23'},
#                'college': 'Duke',
#                'firstname': 'Seth',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 123,
#                'lastname': 'Curry',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 30,
#                                         'pos': 'G'}},
#                'nba': {'pro': 7, 'start': 2013},
#                'weight': {'kilograms': '83.9', 'pounds': '185'}},
#               {'affiliation': 'Davidson/USA',
#                'birth': {'country': 'USA', 'date': '1988-03-14'},
#                'college': 'Davidson',
#                'firstname': 'Stephen',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 124,
#                'lastname': 'Curry',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 30,
#                                         'pos': 'G'}},
#                'nba': {'pro': 12, 'start': 2009},
#                'weight': {'kilograms': '83.9', 'pounds': '185'}},
#               {'affiliation': 'Virginia Commonwealth/USA',
#                'birth': {'country': 'USA', 'date': '1991-07-15'},
#                'college': 'Virginia Commonwealth',
#                'firstname': 'Troy',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 125,
#                'lastname': 'Daniels',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 30,
#                                         'pos': 'G'}},
#                'nba': {'pro': 7, 'start': 2013},
#                'weight': {'kilograms': '90.7', 'pounds': '200'}},
#               {'affiliation': 'Kentucky/USA',
#                'birth': {'country': 'USA', 'date': '1993-03-11'},
#                'college': 'Kentucky',
#                'firstname': 'Anthony',
#                'height': {'feets': '6', 'inches': '10', 'meters': '2.08'},
#                'id': 126,
#                'lastname': 'Davis',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 3,
#                                         'pos': 'F-C'}},
#                'nba': {'pro': 9, 'start': 2012},
#                'weight': {'kilograms': '114.8', 'pounds': '253'}},
#               {'affiliation': 'Michigan State/USA',
#                'birth': {'country': 'USA', 'date': '1996-12-02'},
#                'college': 'Michigan State',
#                'firstname': 'Deyonta',
#                'height': {'feets': '6', 'inches': '11', 'meters': '2.11'},
#                'id': 127,
#                'lastname': 'Davis',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'},
#                            'vegas': {'active': True, 'jersey': 23, 'pos': 'C'}},
#                'nba': {'pro': 3, 'start': 2016},
#                'weight': {'kilograms': '107.5', 'pounds': '237'}},
#               {'affiliation': 'North Carolina/USA',
#                'birth': {'country': 'USA', 'date': '1989-06-05'},
#                'college': 'North Carolina',
#                'firstname': 'Ed',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 128,
#                'lastname': 'Davis',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'C-F'}},
#                'nba': {'pro': 11, 'start': 2010},
#                'weight': {'kilograms': '98.9', 'pounds': '218'}},
#               {'affiliation': 'Southern California/USA',
#                'birth': {'country': 'USA', 'date': '1989-08-12'},
#                'college': 'Southern California',
#                'firstname': 'Dewayne',
#                'height': {'feets': '7', 'inches': '0', 'meters': '2.13'},
#                'id': 131,
#                'lastname': 'Dedmon',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'C'}},
#                'nba': {'pro': 8, 'start': 2013},
#                'weight': {'kilograms': '111.1', 'pounds': '245'}},
#               {'affiliation': 'Wisconsin/USA',
#                'birth': {'country': 'USA', 'date': '1994-05-06'},
#                'college': 'Wisconsin',
#                'firstname': 'Sam',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 132,
#                'lastname': 'Dekker',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 8,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2015},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Virginia Tech/USA',
#                'birth': {'country': 'USA', 'date': '1989-03-11'},
#                'college': 'Virginia Tech',
#                'firstname': 'Malcolm',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 133,
#                'lastname': 'Delaney',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'G'}},
#                'nba': {'pro': 2, 'start': 2016},
#                'weight': {'kilograms': '86.2', 'pounds': '190'}},
#               {'affiliation': 'Southern California/USA',
#                'birth': {'country': 'USA', 'date': '1989-08-07'},
#                'college': 'Southern California',
#                'firstname': 'DeMar',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 136,
#                'lastname': 'DeRozan',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 11,
#                                         'pos': 'G-F'}},
#                'nba': {'pro': 12, 'start': 2009},
#                'weight': {'kilograms': '99.8', 'pounds': '220'}},
#               {'affiliation': 'Colorado/USA',
#                'birth': {'country': 'USA', 'date': '1993-04-06'},
#                'college': 'Colorado',
#                'firstname': 'Spencer',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 142,
#                'lastname': 'Dinwiddie',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 26,
#                                         'pos': 'G'}},
#                'nba': {'pro': 7, 'start': 2014},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': None,
#                'birth': {'country': 'USA', 'date': '1986-03-16'},
#                'college': 'Florida State',
#                'firstname': 'Toney',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 145,
#                'lastname': 'Douglas',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 16,
#                                         'pos': 'G'}},
#                'nba': {'pro': 6, 'start': 2009},
#                'weight': {'kilograms': '88.5', 'pounds': '195'}},
#               {'affiliation': 'Connecticut/USA',
#                'birth': {'country': 'USA', 'date': '1993-08-10'},
#                'college': 'Connecticut',
#                'firstname': 'Andre',
# ...
#                'birth': {'country': 'USA', 'date': '1997-04-17'},
#                'college': 'Tennessee-Chattanooga',
#                'firstname': 'Matt',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 3195,
#                'lastname': 'Ryan',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 37,
#                                         'pos': 'F'},
#                            'vegas': {'active': True, 'jersey': 37, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': 'Mississippi/USA',
#                'birth': {'country': 'USA', 'date': '1998-02-09'},
#                'college': 'Mississippi',
#                'firstname': 'Devontae',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 3203,
#                'lastname': 'Shuler',
#                'leagues': {'vegas': {'active': True, 'jersey': 19, 'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '83.9', 'pounds': '185'}},
#               {'affiliation': 'Clemson/USA',
#                'birth': {'country': 'USA', 'date': '1999-02-17'},
#                'college': 'Clemson',
#                'firstname': 'Aamir',
#                'height': {'feets': '6', 'inches': '8', 'meters': '2.03'},
#                'id': 3205,
#                'lastname': 'Simms',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'F'},
#                            'vegas': {'active': True, 'jersey': 25, 'pos': 'C'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '111.1', 'pounds': '245'}},
#               {'affiliation': "St. John's/USA",
#                'birth': {'country': 'USA', 'date': '1996-05-06'},
#                'college': "St. John's, N.Y.",
#                'firstname': 'Justin',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 3206,
#                'lastname': 'Simon',
#                'leagues': {'vegas': {'active': True, 'jersey': 19, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': 'Pacific/USA',
#                'birth': {'country': 'USA', 'date': '1997-09-22'},
#                'college': 'Pacific',
#                'firstname': 'Jahlil',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 3248,
#                'lastname': 'Tripp',
#                'leagues': {'vegas': {'active': True, 'jersey': 51, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': 'Florida State/USA',
#                'birth': {'country': 'USA', 'date': '1998-03-28'},
#                'college': 'Florida State',
#                'firstname': 'MJ',
#                'height': {'feets': '6', 'inches': '5', 'meters': '1.96'},
#                'id': 3258,
#                'lastname': 'Walker',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 21,
#                                         'pos': 'G'},
#                            'vegas': {'active': True, 'jersey': 21, 'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '96.6', 'pounds': '213'}},
#               {'affiliation': 'DePaul/USA',
#                'birth': {'country': 'USA', 'date': '2001-06-09'},
#                'college': 'DePaul',
#                'firstname': 'Romeo',
#                'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#                'id': 3264,
#                'lastname': 'Weems',
#                'leagues': {'vegas': {'active': True, 'jersey': 1, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '95.3', 'pounds': '210'}},
#               {'affiliation': 'Ohio State/USA',
#                'birth': {'country': 'USA', 'date': '1999-07-27'},
#                'college': 'Ohio State',
#                'firstname': 'Kaleb',
#                'height': {'feets': '6', 'inches': '10', 'meters': '2.08'},
#                'id': 3265,
#                'lastname': 'Wesson',
#                'leagues': {'vegas': {'active': True, 'jersey': 36, 'pos': 'F'}},
#                'nba': {'pro': 1, 'start': 0},
#                'weight': {'kilograms': '114.3', 'pounds': '252'}},
#               {'affiliation': 'Oregon/USA',
#                'birth': {'country': 'USA', 'date': '1995-10-24'},
#                'college': 'Oregon',
#                'firstname': 'Paul',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 3266,
#                'lastname': 'White',
#                'leagues': {'vegas': {'active': True, 'jersey': 52, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '102.1', 'pounds': '225'}},
#               {'affiliation': 'Louisiana State/USA',
#                'birth': {'country': 'USA', 'date': '1998-11-15'},
#                'college': 'Louisiana State',
#                'firstname': 'Emmitt',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 3271,
#                'lastname': 'Williams',
#                'leagues': {'vegas': {'active': True, 'jersey': 30, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '102.1', 'pounds': '225'}},
#               {'affiliation': 'North Carolina/USA',
#                'birth': {'country': 'USA', 'date': '1996-11-18'},
#                'college': 'North Carolina',
#                'firstname': 'Kenny',
#                'height': {'feets': '6', 'inches': '4', 'meters': '1.93'},
#                'id': 3272,
#                'lastname': 'Williams',
#                'leagues': {'vegas': {'active': True, 'jersey': 24, 'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '83.9', 'pounds': '185'}},
#               {'affiliation': 'Gonzaga/USA',
#                'birth': {'country': 'USA', 'date': '1996-11-16'},
#                'college': 'Gonzaga',
#                'firstname': 'Ryan',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 3277,
#                'lastname': 'Woolridge',
#                'leagues': {'vegas': {'active': True, 'jersey': 31, 'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '79.4', 'pounds': '175'}},
#               {'affiliation': 'Georgia Tech/USA',
#                'birth': {'country': 'USA', 'date': '1998-12-23'},
#                'college': 'Georgia Tech',
#                'firstname': 'Moses',
#                'height': {'feets': '6', 'inches': '9', 'meters': '2.06'},
#                'id': 3278,
#                'lastname': 'Wright',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 5,
#                                         'pos': 'F'},
#                            'vegas': {'active': True, 'jersey': 5, 'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '105.7', 'pounds': '233'}},
#               {'affiliation': 'St. Louis/USA',
#                'birth': {'country': 'USA', 'date': '1998-10-23'},
#                'college': 'St. Louis',
#                'firstname': 'Jordan',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3341,
#                'lastname': 'Goodwin',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 7,
#                                         'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Wisconsin/USA',
#                'birth': {'country': 'USA', 'date': '1998-04-06'},
#                'college': 'Wisconsin',
#                'firstname': 'Micah',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3358,
#                'lastname': 'Potter',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 20,
#                                         'pos': 'C'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Coppin State/USA',
#                'birth': {'country': 'USA', 'date': '1997-05-27'},
#                'college': 'Coppin State',
#                'firstname': 'Anthony',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 3362,
#                'lastname': 'Tarke',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 0},
#                'weight': {'kilograms': '99.8', 'pounds': '220'}},
#               {'affiliation': 'Oklahoma State/USA',
#                'birth': {'country': 'USA', 'date': '1997-09-30'},
#                'college': 'Oklahoma State',
#                'firstname': 'Cameron',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3376,
#                'lastname': 'McGriff',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 8,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Illinois/USA',
#                'birth': {'country': 'USA', 'date': '1995-10-26'},
#                'college': 'Illinois',
#                'firstname': 'Malcolm',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 3380,
#                'lastname': 'Hill',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 14,
#                                         'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '99.8', 'pounds': '220'}},
#               {'affiliation': 'Wisconsin/USA',
#                'birth': {'country': 'USA', 'date': '1997-12-22'},
#                'college': 'Wisconsin',
#                'firstname': 'Aleem',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3394,
#                'lastname': 'Ford',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 12,
#                                         'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Morehead State/USA',
#                'birth': {'country': 'USA', 'date': '1995-01-02'},
#                'college': 'Morehead State',
#                'firstname': 'Xavier',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 3396,
#                'lastname': 'Moon',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 15,
#                                         'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '74.8', 'pounds': '165'}},
#               {'affiliation': 'Cincinnati/USA',
#                'birth': {'country': 'USA', 'date': '1997-09-22'},
#                'college': 'Cincinnati',
#                'firstname': 'Jarron',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3397,
#                'lastname': 'Cumberland',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 34,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Arizona/USA',
#                'birth': {'country': 'USA', 'date': '1999-11-22'},
#                'college': 'Arizona',
#                'firstname': 'Brandon',
#                'height': {'feets': '6', 'inches': '2', 'meters': '1.88'},
#                'id': 3398,
#                'lastname': 'Williams',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 8,
#                                         'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '86.2', 'pounds': '190'}},
#               {'affiliation': 'Chicago State/USA',
#                'birth': {'country': 'USA', 'date': '1994-11-13'},
#                'college': 'Chicago St.',
#                'firstname': 'Trayvon',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3401,
#                'lastname': 'Palmer',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 99,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Detroit Mercy/USA',
#                'birth': {'country': 'USA', 'date': '1995-08-29'},
#                'college': 'Detroit Mercy',
#                'firstname': 'Paris',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3402,
#                'lastname': 'Bass',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'West Virginia/USA',
#                'birth': {'country': 'USA', 'date': '1994-07-30'},
#                'college': 'West Virginia',
#                'firstname': 'Jaysean',
#                'height': {'feets': None, 'inches': None, 'meters': None},
#                'id': 3403,
#                'lastname': 'Paige',
#                'leagues': {'standard': {'active': False,
#                                         'jersey': 42,
#                                         'pos': None}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': None, 'pounds': None}},
#               {'affiliation': 'Oklahoma State/USA',
#                'birth': {'country': 'USA', 'date': '1997-07-28'},
#                'college': 'Oklahoma State',
#                'firstname': 'Lindy',
#                'height': {'feets': '6', 'inches': '6', 'meters': '1.98'},
#                'id': 3404,
#                'lastname': 'Waters III',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': 12,
#                                         'pos': 'F'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '97.5', 'pounds': '215'}},
#               {'affiliation': 'Arizona/USA',
#                'birth': {'country': 'USA', 'date': '1993-08-02'},
#                'college': 'Arizona',
#                'firstname': 'Gabe',
#                'height': {'feets': '6', 'inches': '3', 'meters': '1.9'},
#                'id': 3410,
#                'lastname': 'York',
#                'leagues': {'standard': {'active': True,
#                                         'jersey': None,
#                                         'pos': 'G'}},
#                'nba': {'pro': 0, 'start': 2021},
#                'weight': {'kilograms': '86.2', 'pounds': '190'}}],
#  'results': 915}

# %%
#saves response list as players 
players_data = response['response']

#create an empty list to store each player dictionaries in 
players = []

#loop through the json list
for player in players_data:

    #add each player dictionary to players list 
    players.append(player)

#Displays first player entry
players[0]
# Out:
# {'id': 2,
#  'firstname': 'Quincy',
#  'lastname': 'Acy',
#  'birth': {'date': '1990-10-06', 'country': 'USA'},
#  'nba': {'start': 2012, 'pro': 6},
#  'height': {'feets': '6', 'inches': '7', 'meters': '2.01'},
#  'weight': {'pounds': '240', 'kilograms': '108.9'},
#  'college': 'Baylor',
#  'affiliation': 'Baylor/USA',
#  'leagues': {'standard': {'jersey': 4, 'active': True, 'pos': 'F'}}}

# %%
#Create a dataframe from the players array
players_df = pd.DataFrame(players)

#Display first 5 rows of the df
players_df.head()
# Out:
#    id firstname  lastname                                     birth  \
# 0   2    Quincy       Acy  {'date': '1990-10-06', 'country': 'USA'}
# 1   8  LaMarcus  Aldridge  {'date': '1985-07-19', 'country': 'USA'}
# 2  11      Tony     Allen  {'date': '1982-01-11', 'country': 'USA'}
# 3  13       Lou  Amundson  {'date': '1982-12-07', 'country': 'USA'}
# 4  14     Chris  Andersen  {'date': '1978-07-07', 'country': 'USA'}
#
#                           nba  \
# 0   {'start': 2012, 'pro': 6}
# 1  {'start': 2006, 'pro': 15}
# 2  {'start': 2004, 'pro': 12}
# 3   {'start': 2006, 'pro': 9}
# 4  {'start': 2001, 'pro': 13}
#
#                                              height  \
# 0   {'feets': '6', 'inches': '7', 'meters': '2.01'}
# 1  {'feets': '6', 'inches': '11', 'meters': '2.11'}
# 2   {'feets': '6', 'inches': '4', 'meters': '1.93'}
# 3   {'feets': '6', 'inches': '9', 'meters': '2.06'}
# 4  {'feets': '6', 'inches': '10', 'meters': '2.08'}
#
#                                     weight           college  \
# 0  {'pounds': '240', 'kilograms': '108.9'}            Baylor
# 1  {'pounds': '250', 'kilograms': '113.4'}      Texas-Austin
# 2   {'pounds': '213', 'kilograms': '96.6'}    Oklahoma State
# 3   {'pounds': '220', 'kilograms': '99.8'}  Nevada-Las Vegas
# 4  {'pounds': '245', 'kilograms': '111.1'}             Blinn
#
#           affiliation                                            leagues
# 0          Baylor/USA  {'standard': {'jersey': 4, 'active': True, 'po...
# 1    Texas-Austin/USA  {'standard': {'jersey': 21, 'active': True, 'p...
# 2  Oklahoma State/USA  {'standard': {'jersey': 9, 'active': False, 'p...
# 3                None  {'standard': {'jersey': 17, 'active': False, '...
# 4                None  {'standard': {'jersey': None, 'active': False,...

# %%
#Check column types
players_df.dtypes
# Out:
# id              int64
# firstname      object
# lastname       object
# birth          object
# nba            object
# height         object
# weight         object
# college        object
# affiliation    object
# leagues        object
# dtype: object

# %%
#change column types to strings
players_df = players_df.convert_dtypes()

#recheck column types
players_df.dtypes
# Out:
# id              Int64
# firstname      string
# lastname       string
# birth          object
# nba            object
# height         object
# weight         object
# college        string
# affiliation    string
# leagues        object
# dtype: object

# %%
#create a function to identify columns that are object type
def is_array_of_dicts(column_name):
    #create an empty list
    lib_column_names = []

    #loop through columns in the dataframe
    for column_name in players_df.columns:
        
        #checks if the column type is equal to object
        if players_df[column_name].dtype == 'object':

            #adds the column name to the list
            lib_column_names.append(column_name)
    #return the list of object columns        
    return lib_column_names

#create a function to split the dictionaries in the object columns
def split_and_concat_columns(df, columns_to_split):

    #loop through the given columns
    for name in columns_to_split:

        #splits the library into two columns
        split_columns = df[name].apply(pd.Series)
        
        #organizes new columns to match
        df = pd.concat([df, split_columns], axis=1)
        
        #drops the original column
        df = df.drop(name,axis=1)
    
    #returns the new dataframe
    return df

#run the functions to split the columns with dictionaries as values
players_df = split_and_concat_columns(players_df,is_array_of_dicts(players_df.columns))

#display sample from dataframe
players_df.head()
# Out:
#    id firstname  lastname           college         affiliation        date  \
# 0   2    Quincy       Acy            Baylor          Baylor/USA  1990-10-06
# 1   8  LaMarcus  Aldridge      Texas-Austin    Texas-Austin/USA  1985-07-19
# 2  11      Tony     Allen    Oklahoma State  Oklahoma State/USA  1982-01-11
# 3  13       Lou  Amundson  Nevada-Las Vegas                <NA>  1982-12-07
# 4  14     Chris  Andersen             Blinn                <NA>  1978-07-07
#
#   country  start  pro feets inches meters pounds kilograms  \
# 0     USA   2012    6     6      7   2.01    240     108.9
# 1     USA   2006   15     6     11   2.11    250     113.4
# 2     USA   2004   12     6      4   1.93    213      96.6
# 3     USA   2006    9     6      9   2.06    220      99.8
# 4     USA   2001   13     6     10   2.08    245     111.1
#
#                                           standard vegas africa sacramento
# 0        {'jersey': 4, 'active': True, 'pos': 'F'}   NaN    NaN        NaN
# 1     {'jersey': 21, 'active': True, 'pos': 'C-F'}   NaN    NaN        NaN
# 2     {'jersey': 9, 'active': False, 'pos': 'G-F'}   NaN    NaN        NaN
# 3      {'jersey': 17, 'active': False, 'pos': 'F'}   NaN    NaN        NaN
# 4  {'jersey': None, 'active': False, 'pos': 'F-C'}   NaN    NaN        NaN

# %%
#drop new unnecessary columns
players_df = players_df.drop(['meters', 'kilograms', 'vegas', 'africa','sacramento'],axis =1)

#recheck column types
print(players_df.dtypes)

#display new df
players_df.head()
# Out:
# id              Int64
# firstname      string
# lastname       string
# college        string
# affiliation    string
# date           object
# country        object
# start           int64
# pro             int64
# feets          object
# inches         object
# pounds         object
# standard       object
# dtype: object
#    id firstname  lastname           college         affiliation        date  \
# 0   2    Quincy       Acy            Baylor          Baylor/USA  1990-10-06
# 1   8  LaMarcus  Aldridge      Texas-Austin    Texas-Austin/USA  1985-07-19
# 2  11      Tony     Allen    Oklahoma State  Oklahoma State/USA  1982-01-11
# 3  13       Lou  Amundson  Nevada-Las Vegas                <NA>  1982-12-07
# 4  14     Chris  Andersen             Blinn                <NA>  1978-07-07
#
#   country  start  pro feets inches pounds  \
# 0     USA   2012    6     6      7    240
# 1     USA   2006   15     6     11    250
# 2     USA   2004   12     6      4    213
# 3     USA   2006    9     6      9    220
# 4     USA   2001   13     6     10    245
#
#                                           standard
# 0        {'jersey': 4, 'active': True, 'pos': 'F'}
# 1     {'jersey': 21, 'active': True, 'pos': 'C-F'}
# 2     {'jersey': 9, 'active': False, 'pos': 'G-F'}
# 3      {'jersey': 17, 'active': False, 'pos': 'F'}
# 4  {'jersey': None, 'active': False, 'pos': 'F-C'}

# %%
#change the date column to datetime
players_df['date'] = pd.to_datetime(players_df['date'])

#convert other columns from obects to string if possible
players_df = players_df.convert_dtypes()

#recheck datatypes
print(players_df.dtypes)

#visualize dataframe
players_df.head()
# Out:
# id                      Int64
# firstname              string
# lastname               string
# college                string
# affiliation            string
# date           datetime64[ns]
# country                string
# start                   Int64
# pro                     Int64
# feets                  string
# inches                 string
# pounds                 string
# standard               object
# dtype: object
#    id firstname  lastname           college         affiliation       date  \
# 0   2    Quincy       Acy            Baylor          Baylor/USA 1990-10-06
# 1   8  LaMarcus  Aldridge      Texas-Austin    Texas-Austin/USA 1985-07-19
# 2  11      Tony     Allen    Oklahoma State  Oklahoma State/USA 1982-01-11
# 3  13       Lou  Amundson  Nevada-Las Vegas                <NA> 1982-12-07
# 4  14     Chris  Andersen             Blinn                <NA> 1978-07-07
#
#   country  start  pro feets inches pounds  \
# 0     USA   2012    6     6      7    240
# 1     USA   2006   15     6     11    250
# 2     USA   2004   12     6      4    213
# 3     USA   2006    9     6      9    220
# 4     USA   2001   13     6     10    245
#
#                                           standard
# 0        {'jersey': 4, 'active': True, 'pos': 'F'}
# 1     {'jersey': 21, 'active': True, 'pos': 'C-F'}
# 2     {'jersey': 9, 'active': False, 'pos': 'G-F'}
# 3      {'jersey': 17, 'active': False, 'pos': 'F'}
# 4  {'jersey': None, 'active': False, 'pos': 'F-C'}

# %%
#split the 'standard' column
players_df = split_and_concat_columns(players_df,is_array_of_dicts(players_df['standard']))

#display dataframe
players_df.head()
# Out:
#    id firstname  lastname           college         affiliation       date  \
# 0   2    Quincy       Acy            Baylor          Baylor/USA 1990-10-06
# 1   8  LaMarcus  Aldridge      Texas-Austin    Texas-Austin/USA 1985-07-19
# 2  11      Tony     Allen    Oklahoma State  Oklahoma State/USA 1982-01-11
# 3  13       Lou  Amundson  Nevada-Las Vegas                <NA> 1982-12-07
# 4  14     Chris  Andersen             Blinn                <NA> 1978-07-07
#
#   country  start  pro feets inches pounds  jersey active  pos   0
# 0     USA   2012    6     6      7    240     4.0   True    F NaN
# 1     USA   2006   15     6     11    250    21.0   True  C-F NaN
# 2     USA   2004   12     6      4    213     9.0  False  G-F NaN
# 3     USA   2006    9     6      9    220    17.0  False    F NaN
# 4     USA   2001   13     6     10    245     NaN  False  F-C NaN

# %%
#drop 0 column
players_df = players_df.drop([0],axis =1)

#display dataframe
players_df.head()
# Out:
#    id firstname  lastname           college         affiliation       date  \
# 0   2    Quincy       Acy            Baylor          Baylor/USA 1990-10-06
# 1   8  LaMarcus  Aldridge      Texas-Austin    Texas-Austin/USA 1985-07-19
# 2  11      Tony     Allen    Oklahoma State  Oklahoma State/USA 1982-01-11
# 3  13       Lou  Amundson  Nevada-Las Vegas                <NA> 1982-12-07
# 4  14     Chris  Andersen             Blinn                <NA> 1978-07-07
#
#   country  start  pro feets inches pounds  jersey active  pos
# 0     USA   2012    6     6      7    240     4.0   True    F
# 1     USA   2006   15     6     11    250    21.0   True  C-F
# 2     USA   2004   12     6      4    213     9.0  False  G-F
# 3     USA   2006    9     6      9    220    17.0  False    F
# 4     USA   2001   13     6     10    245     NaN  False  F-C

# %%
#drop rows with null, none, or <NA> values
players_df = players_df.dropna()

#reset the dataframe index
players_df.reset_index(inplace=True)

#recheck column types
print(players_df.dtypes)

#display dataframe
players_df.head()
# Out:
# index                   int64
# id                      Int64
# firstname              string
# lastname               string
# college                string
# affiliation            string
# date           datetime64[ns]
# country                string
# start                   Int64
# pro                     Int64
# feets                  string
# inches                 string
# pounds                 string
# jersey                float64
# active                 object
# pos                    object
# dtype: object
#    index  id firstname  lastname         college         affiliation  \
# 0      0   2    Quincy       Acy          Baylor          Baylor/USA
# 1      1   8  LaMarcus  Aldridge    Texas-Austin    Texas-Austin/USA
# 2      2  11      Tony     Allen  Oklahoma State  Oklahoma State/USA
# 3      5  15      Alan  Anderson  Michigan State  Michigan State/USA
# 4      7  17    Justin  Anderson        Virginia        Virginia/USA
#
#         date country  start  pro feets inches pounds  jersey active  pos
# 0 1990-10-06     USA   2012    6     6      7    240     4.0   True    F
# 1 1985-07-19     USA   2006   15     6     11    250    21.0   True  C-F
# 2 1982-01-11     USA   2004   12     6      4    213     9.0  False  G-F
# 3 1982-10-16     USA   2005    7     6      6    220     9.0  False  F-G
# 4 1993-11-19     USA   2015    5     6      5    231    10.0   True  F-G

# %%
#Change height, weight, and jersy values to integers
players_df['feets'] = players_df['feets'].astype(int)
players_df['inches'] = players_df['inches'].astype(int)
players_df['pounds'] = players_df['pounds'].astype(int)
players_df['jersey'] = players_df['jersey'].astype(int)

#recheck datatypes
print(players_df.dtypes)
#display sample of dataframe
players_df.head()
# Out:
# index                   int64
# id                      Int64
# firstname              string
# lastname               string
# college                string
# affiliation            string
# date           datetime64[ns]
# country                string
# start                   Int64
# pro                     Int64
# feets                   int32
# inches                  int32
# pounds                  int32
# jersey                  int32
# active                 object
# pos                    object
# dtype: object
#    index  id firstname  lastname         college         affiliation  \
# 0      0   2    Quincy       Acy          Baylor          Baylor/USA
# 1      1   8  LaMarcus  Aldridge    Texas-Austin    Texas-Austin/USA
# 2      2  11      Tony     Allen  Oklahoma State  Oklahoma State/USA
# 3      5  15      Alan  Anderson  Michigan State  Michigan State/USA
# 4      7  17    Justin  Anderson        Virginia        Virginia/USA
#
#         date country  start  pro  feets  inches  pounds  jersey active  pos
# 0 1990-10-06     USA   2012    6      6       7     240       4   True    F
# 1 1985-07-19     USA   2006   15      6      11     250      21   True  C-F
# 2 1982-01-11     USA   2004   12      6       4     213       9  False  G-F
# 3 1982-10-16     USA   2005    7      6       6     220       9  False  F-G
# 4 1993-11-19     USA   2015    5      6       5     231      10   True  F-G

# %%
#multiply feets values by 12 and add to the inches column to get full height in inches
players_df['height(in)'] = (players_df['feets'] * 12) + players_df['inches']

#drop feets and inches columns
players_df = players_df.drop(['feets','inches'],axis=1)

#display sample of df
players_df.head()
# Out:
#    index  id firstname  lastname         college         affiliation  \
# 0      0   2    Quincy       Acy          Baylor          Baylor/USA
# 1      1   8  LaMarcus  Aldridge    Texas-Austin    Texas-Austin/USA
# 2      2  11      Tony     Allen  Oklahoma State  Oklahoma State/USA
# 3      5  15      Alan  Anderson  Michigan State  Michigan State/USA
# 4      7  17    Justin  Anderson        Virginia        Virginia/USA
#
#         date country  start  pro  pounds  jersey active  pos  height(in)
# 0 1990-10-06     USA   2012    6     240       4   True    F          79
# 1 1985-07-19     USA   2006   15     250      21   True  C-F          83
# 2 1982-01-11     USA   2004   12     213       9  False  G-F          76
# 3 1982-10-16     USA   2005    7     220       9  False  F-G          78
# 4 1993-11-19     USA   2015    5     231      10   True  F-G          77

# %%
players_df.drop(columns=['index'],inplace=True)
players_df.reset_index(drop=True, inplace=True)
players_df.set_index('id',inplace=True)
players_df
players_df.to_csv('Player_Personal_Data.csv')
players_df.to_json("Player_Personal_data.json")

# %%
players_df_t = players_df.transpose()
players_df_t.head()
players_df_t.to_json("Player_Personal_data_t.json")
